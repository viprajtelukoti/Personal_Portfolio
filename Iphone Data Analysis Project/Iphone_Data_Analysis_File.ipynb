# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = pd.read_csv("apple_products.csv")

# %%
data.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple     49900.0
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple     84900.0
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple     84900.0
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple     77000.0
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple     77000.0
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900.0                  0.0             3431.0              356.0
# 1  84900.0                  0.0             3431.0              356.0
# ...

# %%
data.count()
# Out:
# Product Name           61
# Product URL            62
# Brand                  62
# Sale Price             61
# Mrp                    61
# Discount Percentage    61
# Number Of Ratings      61
# Number Of Reviews      61
# Upc                    61
# Star Rating            61
# Ram                    61
# dtype: int64

# %%
data["Mrp"].max()
# Out:
# 149900.0

# %%
data["Mrp"].min()
# Out:
# 39900.0

# %%
data[data["Mrp"]==149900.0]
# Out:
#                                   Product Name  \
# 24        APPLE iPhone 12 Pro (Silver, 512 GB)
# 41  APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 24  https://www.flipkart.com/apple-iphone-12-pro-s...  Apple    140900.0
# 41  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple    140900.0
#
#          Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 24  149900.0                  6.0              542.0               42.0
# 41  149900.0                  6.0              545.0               42.0
#
#                  Upc  Star Rating   Ram
# 24  MOBFWBYZ5UY6ZBVA          4.5  4 GB
# 41  MOBFWBYZTHSXKMGW          4.5  4 GB

# %%
data[data["Mrp"]==39900.0]
# Out:
#                       Product Name  \
# 52  APPLE iPhone SE (White, 64 GB)
# 57  APPLE iPhone SE (Black, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple     29999.0
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple     29999.0
#
#         Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 52  39900.0                 24.0            95807.0             8154.0
# 57  39900.0                 24.0            95909.0             8161.0
#
#                  Upc  Star Rating   Ram
# 52  MOBFWQ6BGWDVGF3E          4.5  2 GB
# 57  MOBFWQ6BR3MK7AUG          4.5  4 GB

# %%
data[data["Mrp"]>100000]
# Out:
#                                         Product Name  \
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 18       APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# 19          APPLE iPhone 11 Pro (Space Grey, 512 GB)
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 21      APPLE iPhone 11 Pro (Midnight Green, 512 GB)
# 22          APPLE iPhone 11 Pro (Space Grey, 256 GB)
# 24              APPLE iPhone 12 Pro (Silver, 512 GB)
# 25    APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)
# 27            APPLE iPhone 12 Pro (Graphite, 256 GB)
# 30            APPLE iPhone 12 Pro (Graphite, 128 GB)
# 31        APPLE iPhone 12 Pro Max (Graphite, 256 GB)
# 32        APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# 37          APPLE iPhone 12 Pro Max (Silver, 128 GB)
# 39            APPLE iPhone 12 Pro Max (Gold, 128 GB)
# ...

# %%
data["Product Name"]
# Out:
# 0            APPLE iPhone 8 Plus (Gold, 64 GB)
# 1     APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2         APPLE iPhone 8 Plus (Silver, 256 GB)
# 3              APPLE iPhone 8 (Silver, 256 GB)
# 4                APPLE iPhone 8 (Gold, 256 GB)
#                         ...
# 57              APPLE iPhone SE (Black, 64 GB)
# 58             APPLE iPhone 11 (Purple, 64 GB)
# 59              APPLE iPhone 11 (White, 64 GB)
# 60              APPLE iPhone 11 (Black, 64 GB)
# 61                                         NaN
# Name: Product Name, Length: 62, dtype: object

# %%
list(data["Product Name"])[1][6:15].upper().strip()
# Out:
# 'IPHONE 8'

# %%
data["Model Name"] = data["Product Name"].str[6:15]

# %%
data["Model Name"].head()
# Out:
# 0    iPhone 8
# 1    iPhone 8
# 2    iPhone 8
# 3    iPhone 8
# 4    iPhone 8
# Name: Model Name, dtype: object

# %%
data.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple     49900.0
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple     84900.0
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple     84900.0
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple     77000.0
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple     77000.0
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900.0                  0.0             3431.0              356.0
# 1  84900.0                  0.0             3431.0              356.0
# ...

# %%
data.sort_values(by=['Star Rating'],ascending = False)
# Out:
#                                          Product Name  \
# 20    APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 17        APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 16   APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 15              APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 14             APPLE iPhone 11 Pro Max (Gold, 256 GB)
# ..                                                ...
# 23  Apple iPhone SE (White, 256 GB) (Includes EarP...
# 24               APPLE iPhone 12 Pro (Silver, 512 GB)
# 26               APPLE iPhone 12 Mini (White, 128 GB)
# 30             APPLE iPhone 12 Pro (Graphite, 128 GB)
# 61                                                NaN
#
#                                           Product URL  \
# 20  https://www.flipkart.com/apple-iphone-11-pro-m...
# 17  https://www.flipkart.com/apple-iphone-11-pro-m...
# 16  https://www.flipkart.com/apple-iphone-11-pro-m...
# 15  https://www.flipkart.com/apple-iphone-11-pro-m...
# ...
